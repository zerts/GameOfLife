# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sockets = np.array([
    22.3022,
    19.5075,
    10.7609,
    7.71607,
    6.72317,
    5.70114,
    5.26421,
    4.71874,
    4.54605,
    4.32071,
    4.21771,
    3.94134,
    3.84717,
    3.85467,
    3.97668,
        
    3.97668,
    4.11668,
    4.12363,
    4.03664,
    4.09692,
    4.15677,
    4.11638,
    4.07624,
    4.20608,      
    
])

xx = [
    1, 2, 4, 6, 8, 10, 12, 16, 18, 20, 24, 30, 32, 36, 40, 48, 60, 72, 
    80, 90, 96, 102, 144, 160,
]

print(len(xx))

mpi = np.array([
    11.6593,
    8.08975,
    9.16182,
    7.54852,
    6.46938,
    5.86827,
    5.34827,
    5.98023,
    5.17135,
    5.22722,
    5.06294,
    5.00773,
    4.65623,
    5.16954,
    4.74253,
    5.20218,
    6.98149,
    5.28799,
    6.49558,
    7.20664,
    8.40492,
    6.31137,
    8.92998,
    8.91725,
    10.5351,
    13.2586,
    10.2962,
    16.9096,
    19.1776,
])

openmp = np.array([
    11.5766,
    13.639,
    10.0745,
    7.54078,
    6.13058,
    5.03162,
    3.79421,
    3.49805,
    3.14178,
    3.00937,
    2.46142,
    2.23709,
    2.1829,
    1.83997,
    1.6946,
    1.93859,
    1.80576,
    1.61983,
    1.68248,
    1.68738,
    1.6431,
    1.66623,
    1.58899,
    1.46273,
    1.47188,
    1.38994,
    1.40815,
    1.47587,                                                                                                                                                               
    1.40977,
])



threads = np.array([
    25.3184,
    12.5333,
    9.6442,
    7.35837,
    5.88731,
    4.98036,
    3.7768,
    3.39211,
    2.9991,
    2.52166,
    2.35162,
    2.20881,
    1.9738,
    1.76627,
    1.67124,
    1.57268,
    1.65264,
    1.71636,
    1.7096,
    1.6908,
    1.54246,
    1.51916,
    1.56686,
    1.5895,
    1.43179,
    1.40147,
    1.38023,
    1.34824,
    1.37467,
])

sockets = sockets / sockets[0]
mpi = mpi / mpi[0]
openmp = openmp / openmp[0]
threads = threads / threads[0]

x = [
    1, 2, 3, 4, 5, 6, 8, 9, 10, 
    12, 15, 16, 18, 20, 24, 30, 
    32, 36, 40, 45, 48, 60, 72, 
    80, 90, 96, 102, 144, 160
]
# Out:
# 24

# %%
plt.figure(figsize=(16, 10))
plt.plot(xx, 1 / sockets, 'o-', label='sockets')
plt.plot(x, 1 / mpi, 'o-', label='mpi')
plt.plot(x, 1 / threads, 'o-', label='threads')
plt.plot(x, 1 / openmp, 'o-', label='openmp')
plt.legend()
#plt.xticks(np.arange(len(threads)), x)
plt.xlabel('number of workers')
plt.ylabel('acceleration per worker')
plt.yticks(np.arange(0, 20))
plt.grid()
plt.show()
